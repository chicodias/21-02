# %%
import yfinance as yf

aapl= yf.Ticker("aapl")
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
from pycaret.internal.pycaret_experiment import TimeSeriesExperiment

exp = TimeSeriesExperiment()
exp.setup(data=data,session_id=42,fh=365)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-75-ccc2b96af93d> in <module>
# ----> 1 from pycaret.internal.pycaret_experiment import TimeSeriesExperiment
#       2
#       3 exp = TimeSeriesExperiment()
#       4 exp.setup(data=data,session_id=42,fh=365)
#       5
#
# ModuleNotFoundError: No module named 'pycaret.internal.pycaret_experiment'

# %%
aapl_historical = aapl.history(start="2020-06-02", end="2021-06-07", interval="1d")
aapl_historical
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2020-06-02   79.415740   80.081768   78.965117   80.057007   87642800
# 2020-06-03   80.383835   80.765132   79.799510   80.497726  104491200
# 2020-06-04   80.316980   80.621515   79.423162   79.804459   87560400
# 2020-06-05   80.059481   82.139268   80.029771   82.077370  137250400
# 2020-06-08   81.767878   82.597319   81.042430   82.562653   95654400
# ...                ...         ...         ...         ...        ...
# 2021-05-28  125.199422  125.428747  124.182436  124.242256   71311100
# 2021-06-01  124.710865  124.980065  123.574230  123.913223   67637100
# 2021-06-02  123.913221  124.870387  123.683904  124.690918   59278900
# 2021-06-03  124.312050  124.481547  122.766621  123.175415   76229200
# 2021-06-04  123.703850  125.787686  123.484498  125.518478   75169300
#
#             Dividends  Stock Splits
# Date
# 2020-06-02        0.0           0.0
# 2020-06-03        0.0           0.0
# ...

# %%
# retrieve date from aapl_historical
#aapl_historical.index

# join date and close in a new df
pd.DataFrame(aapl_historical['Close'])
# Out:
#                  Close
# Date
# 2020-06-02   80.057007
# 2020-06-03   80.497726
# 2020-06-04   79.804459
# 2020-06-05   82.077370
# 2020-06-08   82.562653
# ...                ...
# 2021-05-28  124.242256
# 2021-06-01  123.913223
# 2021-06-02  124.690918
# 2021-06-03  123.175415
# 2021-06-04  125.518478
#
# [255 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-e44a91e6371c> in <module>
#       1 # create a new array with date and close
# ----> 2 aapl_historical_array = np.concatenate(pd.concat(aapl_historical.index), np.array(aapl_historical['Close']),
#       3                                        axis=1)
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
# ...

# %%
from pycaret.regression import *

clf = setup(data = pd.DataFrame(aapl_historical['Close']), target='Close',
            numeric_features=['Close'],
            fold_strategy='timeseries')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-939d09cd4bc1> in <module>
#       1 from pycaret.regression import *
#       2
# ----> 3 clf = setup(data = pd.DataFrame(aapl_historical['Close']), target='Close',
#       4             numeric_features=['Close'],
#       5             fold_strategy='timeseries')
#
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_d0e4b_ th {
#   text-align: left;
# }
# #T_d0e4b_row0_col0 {
#   text-align: left;
# }
# #T_d0e4b_row0_col1, #T_d0e4b_row0_col2, #T_d0e4b_row0_col3, #T_d0e4b_row0_col4, #T_d0e4b_row0_col5, #T_d0e4b_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d0e4b_row0_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d0e4b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
# ...
